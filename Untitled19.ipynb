# %% [markdown]
# # Рекомандательный системы

# %% [markdown]
# Цели:
# - изучить направления рекомендационных систем
# - изучить метрии и основные алгоритмические подходы
# - получить бейзлайн для дальнейших схожих проетктов

# %% [markdown]
# Рекоменательная система это -

# %% [markdown]
# # DataLoading

# %% [markdown]
# В качестве набора данных был выбран
# https://huggingface.co/datasets/yandex/yambda
#
# В нем сожержится множетсво данных о прослушивании музыки пользователями. На данном примере будет будут проведены эксперименты по точности
#
# При загрузке данных из библиотеки pd.DataFrame(load_dataset("yandex/yambda", data_dir="flat/50m", data_files="multi_event.parquet")
# возникли сложности, загрузка шла слишком долго, поэтому набор данных был скачен вручную
#
# https://huggingface.co/datasets/yandex/yambda/tree/main/flat/50m

# %%
# !pip install fastparquet
# Out:
# Requirement already satisfied: fastparquet in /opt/venv/lib/python3.11/site-packages (2024.11.0)
# Requirement already satisfied: pandas>=1.5.0 in /opt/venv/lib/python3.11/site-packages (from fastparquet) (1.5.3)
# Requirement already satisfied: numpy in /opt/venv/lib/python3.11/site-packages (from fastparquet) (1.26.4)
# Requirement already satisfied: cramjam>=2.3 in /opt/venv/lib/python3.11/site-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in /opt/venv/lib/python3.11/site-packages (from fastparquet) (2025.10.0)
# Requirement already satisfied: packaging in /opt/venv/lib/python3.11/site-packages (from fastparquet) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/venv/lib/python3.11/site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/venv/lib/python3.11/site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas>=1.5.0->fastparquet) (1.17.0)

# %%
import pandas as pd

data = pd.read_parquet("multi_event.parquet", engine="fastparquet")

# %% [markdown]
# Набор данных содержит сделующи колонки:
# played_ratio_pct	track_length_seconds	event_type

# %%
data.head()
# Out:
#    uid  timestamp  item_id  is_organic  played_ratio_pct  \
# 0  100      39420  8326270           0             100.0
# 1  100      39420  1441281           0             100.0
# 2  100      39625   286361           0             100.0
# 3  100      40110   732449           0             100.0
# 4  100      40360  3397170           0              46.0
#
#    track_length_seconds event_type
# 0                 170.0     listen
# 1                 105.0     listen
# 2                 185.0     listen
# 3                 240.0     listen
# 4                 130.0     listen

# %% [markdown]
#  Посмотрим размер набора данных, при работе возникли проблемы с памятью, поэтому было принято решение обрезать набор данных в 2 раза

# %%
HOUR_SECONDS = 60 * 60
DAY_SECONDS = 24 * HOUR_SECONDS


print("Дней в данных:", (data["timestamp"].max() - data["timestamp"].min())//DAY_SECONDS)
# Out:
# Дней в данных: 300

# %%
data = data[data['timestamp'] > 270 * DAY_SECONDS]
data
# Out:
#               uid  timestamp  item_id  is_organic  played_ratio_pct  \
# 2904          100   23366265  1639001           0              10.0
# 2905          100   23366270  3375935           0               0.0
# 2906          100   23366460  4889478           0             100.0
# 2907          100   23366640   651341           0             100.0
# 2908          100   23375105  7416528           0               3.0
# ...           ...        ...      ...         ...               ...
# 47790444  1000000   25961415  3369589           0              99.0
# 47790445  1000000   25961615  8120372           0              99.0
# 47790446  1000000   25961805  1578810           0              99.0
# 47790447  1000000   25962060  3732104           0             100.0
# 47790448  1000000   25962225  2978154           0              74.0
#
#           track_length_seconds event_type
# 2904                     320.0     listen
# 2905                     185.0     listen
# 2906                     190.0     listen
# 2907                     180.0     listen
# 2908                     280.0     listen
# ...                        ...        ...
# 47790444                 185.0     listen
# 47790445                 200.0     listen
# 47790446                 190.0     listen
# 47790447                 255.0     listen
# 47790448                 220.0     listen
#
# [6702224 rows x 7 columns]

# %% [markdown]
# Несмотря на то, что в документации описаны типы событий, повторно посмотрим какие есть и в какой количестве

# %%
import plotly.express as px

fig = px.bar(
    data["event_type"].value_counts().reset_index(),
    x="index",
    y="event_type",
    labels={"index": "Тип события", "event_type": "Количество"},
    title="Распределение event_type"
)

fig.show()

# %% [markdown]
# Можно выделить 2 типа взаимодействия пользователя м аудиодоржной: явные (explicit) - like, unlike, dislike, undislike. Такой тип оценки надержный, он явно показывает понравилась ли песня пользователю или нет.
#
# Другой тип - неявные (implicit) - listen. Таких взаиводейтсвий намного больше, но они не надежные, прослушанная песня еще не признак того, что она понравилась пользователю.

# %% [markdown]
# Наша цель - порекомендовать пользователю некую подборку, из которой бы ему явно что-то понравилось бы. Ориентароваться на оценки like/dislike достаточно сложно, потому что их мало. Поэтому попробуем преобразовать explicit во что-то более явное. Будем считать что человеку нравится песня, если он ее послушал минимум 5 раз.
#
# X, Y - y- список рекомендованных песен который пользоваетль потенциально может послушать,

# %% [markdown]
# ## Метрики

# %% [markdown]
# В рекомендательных системах важно не просто предсказать, какие объекты пользователь может выбрать, но и насколько качественно система ранжирует эти объекты.
# Для оценки таких моделей используются метрики ранжирования, которые показывают,
# насколько хорошо топ-рекомендации совпадают с реальными интересами пользователей.
#
# Наиболее распространённые из них — Precision@K, Recall@K и nDCG@K.
# Они позволяют измерять точность, полноту и качество порядка в списке рекомендаций.
#
# * Precision@K показывает, какая доля рекомендаций оказалась релевантной.
# * Recall@K — какую часть всех релевантных объектов система сумела найти.
# * nDCG@K — оценивает качество порядка, отдавая больший вес верхним позициям.
#
# Precision и Recall просты, но не чувствительны к порядку;
# nDCG сложнее, зато отражает реальное качество ранжирования.

# %%
def precision_at_k(recommended, relevant, k):
    """
    recommended: список рекомендованных элементов (в порядке убывания релевантности)
    relevant: множество (или список) релевантных элементов
    k: количество топовых рекомендаций, которые учитываем
    """
    recommended_at_k = recommended[:k]
    relevant_hits = sum(1 for item in recommended_at_k if item in relevant)
    return relevant_hits / len(recommended_at_k)


def recall_at_k(recommended, relevant, k):
    """
    recommended: список рекомендованных элементов
    relevant: множество релевантных элементов
    k: количество топовых рекомендаций
    """
    recommended_at_k = recommended[:k]
    relevant_hits = sum(1 for item in recommended_at_k if item in relevant)
    return relevant_hits / len(relevant) if len(relevant) > 0 else 0.0


def dcg_at_k(predicted, actual, k):
    return sum(1 / np.log2(i + 2) for i, item in enumerate(predicted[:k]) if item in actual)

def idcg_at_k(actual, k):
    return sum(1 / np.log2(i + 2) for i in range(min(len(actual), k)))

def ndcg_at_k(predicted, actual, k):
    ideal = idcg_at_k(actual, k)
    if ideal == 0:
        return None
    return dcg_at_k(predicted, actual, k) / ideal

# %% [markdown]
# ## Предобработка данных

# %%
data[data["uid"].isna() | data["item_id"].isna()]

# целостность
# Out:
# Empty DataFrame
# Columns: [uid, timestamp, item_id, is_organic, played_ratio_pct, track_length_seconds, event_type]
# Index: []

# %% [markdown]
# Всего данных в набора данных

# %% [markdown]
# #### Дубликаты

# %% [markdown]
# Было обнаружено Видим, что строки не совсем идентичные, доля прослушивания played_ratio_pct разная. Вероятно событие фиксировалось несколько раз. Поэтому дубликаты нужно удалять осторожно, оставляя последнию запись с максиимальны played_ratio_pct

# %%
# Возьмем один из дубликатов и посмотрим на данные 
data[(data["uid"] == 999200)&
    (data["timestamp"] == 25914300)&
    (data["item_id"] == 1779922)&
    (data["event_type"] == "listen")]
# Out:
#              uid  timestamp  item_id  is_organic  played_ratio_pct  \
# 47764487  999200   25914300  1779922           1              44.0
# 47764488  999200   25914300  1779922           1               5.0
# 47764489  999200   25914300  1779922           1             100.0
#
#           track_length_seconds event_type
# 47764487                 260.0     listen
# 47764488                 260.0     listen
# 47764489                 260.0     listen

# %% [markdown]
# Проверим другие столбцы, is_organic не должен дублироваться для одинаковых записей, он должен быть уникальным
# is_organic - почему то может быть размым для некоторых строк. Возьмем для is_organic - среднее. Если получится что одна и та же строка попадает дважы то это будет 0.5, такие строки удалим

# %%
conflicts = (
    data.groupby(["uid", "item_id", "event_type", "timestamp"])["is_organic"]
    .nunique()
    .reset_index(name="unique_values")
)

conflicts = conflicts[conflicts["unique_values"] > 1]
conflicts.head()
# Out:
#           uid  item_id event_type  timestamp  unique_values
# 64473   11900  1116215     listen   24069210              2
# 116036  18800  7829378     listen   25425965              2
# 157539  24600  1171491     listen   23694370              2
# 179938  29600  8351511     listen   24093755              2
# 194298  31800  8574692     listen   23560230              2

# %% [markdown]
# Проверим что item_id и track_length_seconds соотносятся уникально. Таблица пустая - все пары уникальные track_length_seconds берем первый

# %%
dups = (
    data.groupby("item_id")["track_length_seconds"]
    .nunique()
    .reset_index(name="uniq_lengths")
)

# item_id с несколькими track_length_seconds
problem_items = dups[dups["uniq_lengths"] > 1]
problem_items.head()
# Out:
# Empty DataFrame
# Columns: [item_id, uniq_lengths]
# Index: []

# %%
# Возможно пользователь просто перелелистнул быстро и факт прослишишвания был долей секунды, оставляем такие данные

def clean_listen_duclicates(data):

    df_listen = data[data["event_type"] == "listen"]
    df_listen = df_listen.groupby(["uid", "item_id", "event_type", "timestamp"]).agg({"played_ratio_pct":"max",
                                                                                      "is_organic":"mean",
                                                                                      "track_length_seconds": "first"}).reset_index()
    
    df_listen = df_listen[df_listen["is_organic"].isin([1.0,0.0])] 

    return df_listen

# %%
# Проверка процента прослушивания (не может быть более 100%)
def remove_not_valid_listen_data(df_listen):
    return df_listen[ df_listen["played_ratio_pct"].between(0, 100)]

# %%
df_listen = data[data["event_type"] == "listen"]
print(len(df_listen))
df_listen = clean_listen_duclicates(df_listen)

print(len(df_listen))
df_listen = remove_not_valid_listen_data(df_listen)
print(len(df_listen))
# Out:
# 6507669
# 6410880
# 6380437

# %% [markdown]
# Распределение

# %%
def cut_track_len(df, limit):
    return df[df['track_length_seconds'] < limit]

# %%
import plotly.express as px
fig = px.bar(
    df_listen["track_length_seconds"].value_counts().reset_index(),
    x="index",
    y="track_length_seconds"
)

fig.show()

# %% [markdown]
# Скорее всего это подкасты или склейки. Вероятность прослушивания таких долгих песен сильно ниже и может негативно повлиять на статистику. Поэтому такие песни удаляются из работы. Но такое будем применять только для обучающей выборки

# %%
df_listen_all = cut_track_len(df_listen, 600) 
import plotly.express as px
fig = px.bar(
    df_listen_all['track_length_seconds'].value_counts().reset_index(),
    x="index",
    y="track_length_seconds"
)

fig.show()

# %% [markdown]
# Дубликаты лайки

# %% [markdown]
# В один и тот же момент было получено несколько лайков и дизлайков. Возможно пользователь кликал несколько раз не пенсю или произошел сбой в системе. Кроме того, могли произойти ситуации когда человек сначала лайкнул, потом через время убрал лайк и тд

# %%
df_like = data[data["event_type"] != "listen"]

df_like[(df_like["uid"] == 900)&
        # (df_like["timestamp"] == 25457490)&
        (df_like["item_id"] == 3385274)&
        ~(df_like["event_type"] == "listen")][["timestamp", "event_type"]].value_counts()
# Out:
# timestamp  event_type
# 25457490   unlike        16
#            like          16
# 25457460   like           1
# 25457470   unlike         1
# 25457480   like           1
# 25457485   unlike         1
#            like           1
# 25514485   dislike        1
# 25514645   like           1
# dtype: int64

# %% [markdown]
# В таком случае будем оставлять записи по последнему таймстемпу (по индексу так как таймстемп может быть обрезан в секундах)
#
#
#
# В каждом из набора данных обработаем event. По timestemp посмотрим какое последнее было действие в промежутке.
# like -> like
# unlike -> dislike
# dislike  -> dislike
# undislike -> like
#
# Мы не можем делать это на весь датасет потому что к примеру после рекомендации мнение пользователя может поменяться, поэтому смотрим отдельно по выборкам
#
#
# Для упрошения обработки оставим просто последнюю реакцию пользователя и переименуем ее в соответствии с правилами
# Нужно выбрать только те строки где запими train_df["event_type"] == "like"

# %%
def convert_reaction(df):

    reaction_events = ["like", "unlike", "dislike", "undislike"]

    reactions_df = df[df["event_type"].isin(reaction_events)].copy()
    
    last_reactions = (
        reactions_df.groupby(["uid", "item_id"], as_index=False)
                    .last()  # последнее событие в списке
    )
    return last_reactions

event_map = {
    "like": "like",
    "unlike": "dislike",
    "dislike": "dislike",
    "undislike": "like",
    "listen": "listen"
}

def rename_events(df):
    df["event_type"] = df["event_type"].map(event_map)
    return  df

# %% [markdown]
# <!-- # В каждом из набора данных обработаем event. По timestemp посмотрим какое последнее было действие в промежутке.
# # like -> like
# # unlike -> dislike
# # dislike  -> dislike
# # undislike -> like
#
# # Мы не можем делать это на весь датасет потому что к примеру после рекомендации мнение пользователя может поменяться, поэтому смотрим отдельно по выборкам
#
#
# # Для упрошения обработки оставим просто последнюю реакцию пользователя и переименуем ее в соответствии с правилами
# # Нужно выбрать только те строки где запими train_df["event_type"] == "like" -->

# %%
df_like = convert_reaction(df_like)

fig = px.bar(
    df_like["event_type"].value_counts().reset_index(),
    x="index",
    y="event_type",
    labels={"index": "Тип события", "event_type": "Количество"},
    title="Распределение event_type"
)

fig.show()
df_like = rename_events(df_like)

fig = px.bar(
    df_like["event_type"].value_counts().reset_index(),
    x="index",
    y="event_type",
    labels={"index": "Тип события", "event_type": "Количество"},
    title="Распределение event_type"
)

fig.show()

# %% [markdown]
# ## Кодирование данных
#
#
# кодируем uid и item_id в числовые индексы, чтобы модели и алгоритмы могли с ними работать.
#
# Строковые ID нельзя напрямую подать в матрицу взаимодействий или Embedding-слой, поэтому мы переводим их в диапазон 0..N.
# Это нужно для эффективности (память, скорость), совместимости с моделями (Matrix Factorization, Embeddings) и стабильного маппинга между train и test.

# %%
def codic_of_index(train_df, test_df):
    
    user_id_map = {uid: idx for idx, uid in enumerate(train_df["uid"].unique())}
    item_id_map = {iid: idx for idx, iid in enumerate(train_df["item_id"].unique())}
    
    train_df["uid"] = train_df["uid"].map(user_id_map)
    train_df["item_id"] = train_df["item_id"].map(item_id_map)
    
    test_df["uid"] = test_df["uid"].map(user_id_map)
    test_df["item_id"] = test_df["item_id"].map(item_id_map)

    return train_df, test_df

# %% [markdown]
# ## Test/train split

# %% [markdown]
# Сразу разделим данные на тестову и обучающую выборку.
#
# Деление будет по временному признаку.
# Чтобы исключить dataLeakege (когда признаки, рассчитанные на истории,
# могут «заглядывать» в будущее), вставим временной зазор (gap)
#
# В оригинальной статье https://www.arxiv.org/pdf/2505.22238 берется соотношение 300, 30мин, 1 день
#
# Лучшие результаты у меня получились при  80, 30мин, 20 день
#
# Чтобы приблизиться к условиям статьи буду снижать размер теста но при этом обучающая выборка остается гиперпараметром

# %%
GAP_SIZE = HOUR_SECONDS // 2
TEST_SIZE = 1 * DAY_SECONDS

LAST_TIMESTAMP = data["timestamp"].max()

TEST_TIMESTAMP = LAST_TIMESTAMP - TEST_SIZE

TRAIN_TIMESTAMP = TEST_TIMESTAMP - GAP_SIZE

# %% [markdown]
# ### Pipeline

# %%
train_df = data[data['timestamp'] < TRAIN_TIMESTAMP]
test_df = data[data['timestamp'] > TEST_TIMESTAMP]

train_df, test_df = codic_of_index(train_df, test_df)

train_df_likes = train_df[~(train_df["event_type"] == "listen")]
test_df_likes = test_df[~(test_df["event_type"] == "listen")]

train_df_listen = train_df[train_df["event_type"] == "listen"]
test_df_listen = test_df[test_df["event_type"] == "listen"]

print("Train data (listens)")
print(len(train_df_listen))

train_df_listen = clean_listen_duclicates(train_df_listen)
print(len(train_df_listen))
train_df_listen = remove_not_valid_listen_data(train_df_listen)
print(len(train_df_listen))
train_df_listen = cut_track_len(train_df_listen, 600) 
print(len(train_df_listen))


print("Test data (listens)")
print(len(test_df_listen))

test_df_listen = clean_listen_duclicates(test_df_listen)
print(len(test_df_listen))
test_df_listen = remove_not_valid_listen_data(test_df_listen)
print(len(test_df_listen))


print("Train data (likes)")
print(len(train_df_likes))
train_df_likes = convert_reaction(train_df_likes)
train_df_likes = rename_events(train_df_likes)
print(len(train_df_likes))

print("Test data (likes)")
print(len(test_df_likes))
test_df_likes = convert_reaction(test_df_likes)
test_df_likes = rename_events(test_df_likes)
print(len(test_df_likes))


test_df = pd.concat([test_df_likes,test_df_listen ]) 

train_df = pd.concat([train_df_likes,train_df_listen ])
# Out:
# /tmp/ipykernel_18220/1608591273.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_18220/1608591273.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_18220/1608591273.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_18220/1608591273.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Train data (listens)
# 6273679
# 6192484
# 6163103
# 6140431
# Test data (listens)
# 232040
# 209593
# 208575
# Train data (likes)
# 188133
# 168384
# Test data (likes)
# 6358
# 5297

# %% [markdown]
# ### Очистка

# %% [markdown]
# ## Baseline topK

# %% [markdown]
# Как бейзлайн возьмем топ 10 понравившихся песен всем пользователем. Возьмем именно по лайкам, так как они наиболее надежные чем прослушивания (однако для чистоты эксперимента были провериины и этот вариант, точность оказалась ниже)

# %%
# get top 10 popular itemspopular items

top_10_likes = train_df[train_df["event_type"] == "like"]["item_id"].value_counts()[:10]

top_10_by_unique_users = (
    train_df[train_df["event_type"] == "listen"]
    .groupby("item_id")["uid"]
    .nunique()
    .sort_values(ascending=False)
    .head(10)
)

top_10_by_unique_users
# Out:
# item_id
# 1773    2608
# 3611    2096
# 4741    2082
# 3725    2051
# 2916    1983
# 470     1958
# 6213    1697
# 3718    1686
# 4081    1678
# 1969    1630
# Name: uid, dtype: int64

# %%
import pandas as pd

def combine_top_series(top_series: dict[str, pd.Series], weights: dict[str, float], top_n: int = 10):
    """
    Объединяет несколько Series (топы) в один общий рейтинг с весами.

    Parameters
    ----------
    top_series : dict[str, pd.Series]
        Словарь с названиями метрик и их Series (item_id -> значение).
        Пример: {"likes": s1, "listeners": s2, "ratings": s3}
    weights : dict[str, float]
        Веса для каждой метрики, например {"likes": 0.9, "listeners": 0.7, "ratings": 0.5}
    top_n : int
        Размер итогового топа.

    Returns
    -------
    result_df : pd.DataFrame
        Таблица с нормализованными значениями, итоговым скором и отсортированным топом.
    top_items : list
        Список item_id в порядке убывания суммарного score.
    """
    # объединяем все Series в одну таблицу
    summary = pd.concat(top_series.values(), axis=1, keys=top_series.keys()).fillna(0)
    
    # нормируем каждую колонку в [0,1]
    for col in top_series.keys():
        max_val = summary[col].max()
        summary[f"{col}_norm"] = summary[col] / max_val if max_val != 0 else 0

    # вычисляем общий скор
    score = 0
    for name, weight in weights.items():
        norm_col = f"{name}_norm"
        if norm_col not in summary:
            raise ValueError(f"Метрика '{name}' отсутствует в top_series.")
        score += summary[norm_col] * weight

    summary["score"] = score

    # сортируем и выбираем топ
    top_df = summary.sort_values("score", ascending=False).head(top_n)
    top_items = top_df.index.tolist()

    return top_df, top_items



# задаём веса
weights = {"likes": 0.9, "listeners": 0.7}

# объединяем
top_df, top_items = combine_top_series(
    top_series={
        "likes": top_10_likes,
        "listeners": top_10_by_unique_users,
        # "ratings": top_10_ratings
    },
    weights=weights,
    top_n=10
)

top_10_overall = top_df.index.tolist()

# %%
from collections import defaultdict
import numpy as np
 
grouped_users = test_df.groupby("uid")
overall_recall = []
overall_ndcg = []
for uid, group in grouped_users:
    # print(list(group["item_id"]))
    user_true = list(set(group["item_id"]))
    recall = recall_at_k(top_10_overall, user_true,  10)
    # print(precision)
    ndcg = ndcg_at_k(top_10_overall ,user_true,  10)
    overall_recall.append(recall)
    overall_ndcg.append(ndcg)

print(np.mean(overall_recall))
print(np.mean(overall_ndcg))
# Out:
# 0.010083062482756753
# 0.02523272265333282

# %%
import plotly.graph_objects as go

def plot_metric_with_benchmark(
    metric_name: str,
    metric_values: list[float],
    experiment_names: list[str],
    benchmark_value: float | None = None,
    dashed: bool = False,
    fill_color: str = "rgba(255, 0, 0, 0.1)"  # красный с прозрачностью
):
    """
    Рисует график метрики по экспериментам + горизонтальную линию-бенчмарк
    + подсветку (заливку) до линии бенчмарка.
    """

    if len(metric_values) != len(experiment_names):
        raise ValueError("Длины metric_values и experiment_names должны совпадать")

    fig = go.Figure()

    # === Основная линия метрики ===
    fig.add_trace(go.Scatter(
        x=experiment_names,
        y=metric_values,
        mode="lines+markers+text",
        name=metric_name,
        text=[f"{v:.3f}" for v in metric_values],
        textposition="top center",
        line=dict(width=3, dash="dash" if dashed else "solid"),
        marker=dict(size=8)
    ))

    # === Горизонтальная линия-бенчмарк ===
    if benchmark_value is not None:
        # Заливка до бенчмарка
        fig.add_trace(go.Scatter(
            x=[experiment_names[0], experiment_names[-1], experiment_names[-1], experiment_names[0]],
            y=[0, 0, benchmark_value, benchmark_value],
            fill="toself",
            fillcolor=fill_color,
            line=dict(color="rgba(255,0,0,0)"),  # без контура
            hoverinfo="skip",
            showlegend=False
        ))

        # Линия-бенчмарк
        fig.add_trace(go.Scatter(
            x=[experiment_names[0], experiment_names[-1]],
            y=[benchmark_value, benchmark_value],
            mode="lines",
            name=f"{metric_name} benchmark ({benchmark_value:.3f})",
            line=dict(width=2, dash="dot", color="red")
        ))

    # === Настройки осей и оформления ===
    y_max = max(metric_values + ([benchmark_value] if benchmark_value else [0])) * 1.25

    fig.update_layout(
        title=f"📈 {metric_name} по экспериментам (с бенчмарком)",
        xaxis_title="Эксперимент",
        yaxis_title=metric_name,
        yaxis=dict(range=[0, y_max]),
        template="plotly_white",
        hovermode="x unified",
        legend=dict(
            orientation="h",
            yanchor="bottom",
            y=1.02,
            xanchor="center",
            x=0.5
        )
    )

    return fig



experiments = [
    "MostPop train 29, test 1",
    "MostPop _by_unique_users",
    "MostPop combined",
    "iALS",
    "iALS+formula of score",
    "iALS+apply preprocess",
    "iALS+apply weight by %",
]




recall_scores = [0.89, 0.70, 1.00, 3.6, 4.2, 4.3, 4.45]
ndcg_scores   = [2.25, 2.41, 2.55, 8.93, 10.5, 10.7, 11.11]

# 1) график Recall@10
fig_recall = plot_metric_with_benchmark(
    "Recall@10", recall_scores, experiments,
    benchmark_value=3.7,    # максимум авторов по Recall
    dashed=False
)
fig_recall.show()

# 2) график NDCG@10
fig_ndcg = plot_metric_with_benchmark(
    "NDCG@10", ndcg_scores, experiments,
    benchmark_value=7.81,    # максимум авторов по NDCG
    dashed=False              # отличим стиль линий, если хочешь
)
fig_ndcg.show()

# После ужесточения условий точность просела - что логично. ПРи очиске лайков особо ничего не поменялось а так же при 
# На ранних этапах было принято решение увеличить время предсказания так как 1 день слишком жестко а 299 на трейне слишком много, много обобщения
# для ALS пришлось повысить длину вектора

# %% [markdown]
# ### Коллаборативная фильтрация | ALS

# %% [markdown]
# Обучение модели
#
# AlternatingLeastSquares (ALS) — это модель матричной факторизации для неявных откликов (implicit feedback).
# Она раскладывает матрицу взаимодействий пользователей и объектов на две матрицы эмбеддингов — пользователей и айтемов — так, чтобы их скалярное произведение предсказывало интерес.
# Обучается поочерёдным решением задач наименьших квадратов: сначала фиксирует айтемы и обновляет пользователей, потом наоборот.
#
#
# В одной итерации ALS поочерёдно пересчитывает вектора пользователей и айтемов.
# Сначала, при фиксированных айтемах, решаются задачи наименьших квадратов для всех пользователей;
# потом, при фиксированных пользователях — для всех айтемов.
# Это повторяется несколько итераций, пока модель не сойдётся.

# %% [markdown]
# подготовка данных так как тут implicit метки, меняем их. Считаем сколько раз человек послуша ту или иную песню

# %% [markdown]
# Формируем матрицу для разложения

# %% [markdown]
# ### Посмотрим распределение количества данных

# %%
# Применим логорифмирование -не особо помогло. Поставим порог при котором считаем что песня нам понравилась

# %%
# Делай отрицательное
train_df_implicit = (
    train_df[train_df["event_type"] == "listen"]
    .groupby(['uid', 'item_id'])
    .agg({
        'timestamp': 'count',
        'played_ratio_pct': 'mean'   # среднее процент прослушивания по всем сессиям
    })
    .reset_index()
)

train_df_implicit["timestamp"] = train_df_implicit["timestamp"]*(train_df_implicit["played_ratio_pct"]/100)
train_df_implicit["timestamp"] = np.log1p(train_df_implicit["timestamp"]) 
# train_df_implicit.loc["timestamp"] = (train_df_implicit["played_ratio_pct"] / 100)*5 + train_df_implicit["timestamp"]


train_df_dislike = train_df[train_df["event_type"]=="dislike"].groupby(['uid','item_id'])['timestamp'].count().reset_index()
train_df_dislike['timestamp'] = - train_df_dislike['timestamp']
train_df_dislike.loc[train_df_dislike["timestamp"] < 0, "timestamp"] = 1



train_df_like = train_df[train_df["event_type"]=="like"].groupby(['uid','item_id'])['timestamp'].count().reset_index()
train_df_like["timestamp"] = 1


train_merge = (
    train_df_implicit
    .merge(train_df_dislike, on=['uid', 'item_id'], how='outer')
    .merge(train_df_like, on=['uid', 'item_id'], how='outer')
    .fillna(0)
)


train_merge["conf"] = (train_merge["timestamp"] * 20.0) + (train_merge["timestamp_y"] * -10) + train_merge["timestamp_x"]

# %%
len(train_merge["uid"].unique())
# len(train_merge["item_id"].unique())
# Out:
# 9947

# %%
from scipy.sparse import coo_matrix
from implicit.nearest_neighbours import tfidf_weight
from implicit.als import AlternatingLeastSquares


rows = train_merge["uid"].to_numpy(np.int32) 
cols = train_merge["item_id"].to_numpy(np.int32) 
data = train_merge["conf"].to_numpy(np.int32) 


alpha = 40.0  # важный гиперпараметр!
confidence =  data

user_item_matrix = coo_matrix((confidence, (rows, cols)))


# сжатие матрицы
user_item_matrix = user_item_matrix.tocsr()

# %%
from implicit.als import AlternatingLeastSquares

model = AlternatingLeastSquares(factors=128, #Размерность скрытых признаков (эмбеддингов)
                                regularization=0.05,
                                iterations=30,
                                alpha=1,
                                random_state=42)
model.fit(user_item_matrix)




# model = AlternatingLeastSquares(
#     factors=128,          # размер эмбеддингов
#     regularization=1e-2,  # L2-регуляризация
#     iterations=20,        # число итераций ALS
#     use_gpu=True,         # если есть видеокарта, иначе False
#     num_threads=0         # 0 = авто по числу ядер
# )
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 30/30 [00:43<00:00,  1.45s/it]

# %%
from tqdm import tqdm
import numpy as np

# %%
# Метод ALS может работать только с данными которые он уже видел. 
# оставляет только тех кто был в обучающей выборке

# test_df_als = test_df.dropna(subset=["uid", "item_id"]).astype({"uid": int, "item_id": int}) 



grouped_users = test_df.groupby("uid")

overall_recall = []
overall_ndcg = []

for uid, group in tqdm(grouped_users):
    # uid из groupby может быть np.int64, а может и float — сразу приводим
    uid_int = int(uid)

    user_true = list(set(group["item_id"]))
    if not user_true:
        continue

    # проверяем, есть ли такой пользователь в train-матрице
    if uid_int < 0 or uid_int >= user_item_matrix.shape[0]:
        is_new_user = True
        user_row = None
    else:
        user_row = user_item_matrix[uid_int]
        is_new_user = (user_row.getnnz() == 0)  # нет интеракций в train

    if is_new_user:
        # cold start: рекомендуем топ-10 популярных
        rec_items = top_10_overall          # np.array / list из 10 item_id
    else:
        # известный пользователь: рекомендации моделью
        rec_items, w_rec = model.recommend(
            userid=uid_int,
            user_items=user_row,
            N=10,
            filter_already_liked_items=False,   
        )

    # print(user_true, rec_items)
    recall = recall_at_k(rec_items, user_true, 10)
    ndcg   = ndcg_at_k(rec_items, user_true, 10)

    overall_recall.append(recall)
    overall_ndcg.append(ndcg)

print("Mean Recall@10:", np.mean(overall_recall))
print("Mean NDCG@10 :", np.mean(overall_ndcg))
# Out:
#   0%|                                                                                    | 6/4976 [00:00<01:43, 47.80it/s]
# [8193.0, 258.0, 255.0, 2947.0, 30465.0, 263.0, 136.0, 16007.0, 12426.0, 21003.0, 14.0, 65551.0, 16.0, 5753.0, 92686.0, 275.0, 24.0, 25.0, 283.0, 285.0, 33.0, 40870.0, 12968.0, 42.0, 299.0, 172.0, 175.0, 6448.0, 11825.0, 179.0, 272435.0, 54.0, 8759.0, 8762.0, 189.0, 8767.0, 192.0, 195.0, 81220.0, 69.0, 197.0, 72.0, 206.0, 209.0, 11261.0, 340.0, 89.0, 217.0, 5851.0, 3036.0, 15995.0, 222.0, 95.0, 225.0, 99.0, 101.0, 230.0, 106.0, 234.0, 12907.0, 45816.0, 379.0, 372.0, 9459.0, 246.0, 254.0, 380.0, 121.0, 122.0, 123.0, 124.0, 381.0, 126.0, 127.0] [   16    95   167   106     3    39   267    24    53  8745  6609  5678
#    174   583  8759  6217   230 12907    10   137]
# [1120.0, 141448.0, 970.0, 1003.0, 752.0, 944.0, 1168.0, 795.0, 958.0] [ 6289  7175  6870   777  6428  4456  6767   688   618  6347  6696  6776
#  33860  6871   613  6867 30012 33818   616  7599]
# [68481.0, 150533.0, 39824.0, 230163.0, 3223.0, 53659.0, 13980.0, 88348.0, 3232.0, 53670.0, 3632.0, 53686.0, 158263.0, 3514.0, 84539.0, 3262.0, 3903.0, 47422.0, 37825.0, 105023.0, 111812.0, 3271.0, 20172.0, 36560.0, 3539.0, 39128.0, 30173.0, 39904.0, 126309.0, 111718.0, 24936.0, 39658.0, 5100.0, 3565.0, 3694.0, 3056.0, 21360.0] [1773  470  571  476 1697 4741 1715 1447 1630 7198 1574 6212 1578  478
#   568 6068  480 1931 1687 3725]
# [95747.0, 388.0, 5381.0, 5764.0, 128388.0, 2441.0, 5390.0, 4241.0, 55441.0, 2579.0, 2835.0, 2581.0, 280.0, 15897.0, 46115.0, 2730.0, 8620.0, 301.0, 40876.0, 140460.0, 304.0, 2352.0, 2610.0, 14007.0, 2619.0, 2493.0, 2374.0, 3014.0, 35784.0, 23498.0, 5328.0, 45905.0, 82.0, 4946.0, 3028.0, 2773.0, 12883.0, 2775.0, 75728.0, 2395.0, 103391.0, 3044.0, 78566.0, 359.0, 40682.0, 2546.0, 36978.0, 46066.0, 46964.0, 25210.0, 63095.0, 8186.0] [ 304 3028  388  173  112 3007  359 2493 2875   84 2950  176 2551 2424
#  2682 2687   38   80  301 2882]
# [85280.0, 27042.0, 3207.0, 32879.0, 115216.0, 14483.0, 24538.0, 73343.0] [ 2081  2076  2078  3056  3064  2862  2942  3262 13338  3510  3200  3702
#   3706  3599  3616  3233  3274  3648  3368  3268]
# [3073.0, 20482.0, 12808.0, 5646.0, 2578.0, 5140.0, 2587.0, 558.0, 561.0, 3646.0, 3658.0, 5708.0, 2643.0, 2647.0, 2650.0, 4187.0, 17500.0, 4190.0, 3680.0, 4204.0, 7790.0, 4719.0, 7791.0, 21106.0, 4215.0, 4224.0, 9861.0, 4232.0, 4744.0, 2700.0, 4237.0, 4238.0, 4240.0, 5267.0, 7831.0, 4250.0, 4252.0, 4256.0, 4257.0, 4265.0, 21162.0, 4269.0, 4273.0, 36037.0, 3782.0, 39112.0, 5326.0, 2777.0, 3298.0, 2787.0, 2789.0, 4848.0, 4339.0, 17144.0, 5881.0, 5891.0, 3847.0, 12556.0, 17686.0, 38685.0, 31008.0, 5922.0, 23332.0, 17197.0, 2353.0, 2356.0, 2359.0, 3389.0, 27968.0, 2370.0, 3394.0, 3396.0, 3909.0, 32068.0, 3919.0, 12113.0, 36184.0, 3929.0, 7515.0, 2398.0, 4454.0, 4456.0, 8040.0, 36206.0, 31087.0, 10609.0, 13171.0, 2937.0, 4474.0, 2433.0, 4486.0, 13193.0, 4496.0, 2961.0, 4498.0, 5527.0, 29086.0, 4520.0, 4010.0, 4522.0, 51630.0, 10673.0, 4530.0, 2997.0, 2489.0, 4544.0, 457.0, 41425.0, 4579.0, 3047.0, 56817.0, 2546.0, 23541.0, 8186.0] [ 457 3776 2700  479 4180 3968 4081 4225 4266 3725 3047 3714 4256  470
#  4192 3680 3658 2492 2944 2770]
# [4353.0, 63874.0, 5378.0, 5634.0, 23681.0, 262.0, 390.0, 5640.0, 5513.0, 26633.0, 5519.0, 8340.0, 54167.0, 46105.0, 5658.0, 5156.0, 39.0, 4904.0, 5544.0, 4394.0, 5290.0, 5419.0, 301.0, 9512.0, 5423.0, 176.0, 3763.0, 308.0, 53.0, 2613.0, 13237.0, 26427.0, 5312.0, 5456.0, 5331.0, 5466.0, 64385.0, 5859.0, 26468.0, 229.0, 23653.0, 5866.0, 5872.0, 20731.0, 5629.0, 296446.0] [  84   38  173   55 5421 2682 2608 5420 5423 5289 2686 3718 2685  176
#   390 5318 5612 2418 5721 5538]
# [6784.0, 6785.0, 291842.0, 6787.0, 779.0, 6926.0, 783.0, 6927.0, 6289.0, 8206.0, 6677.0, 28696.0, 6685.0, 6692.0, 12455.0, 6696.0, 6699.0, 6701.0, 6711.0, 6841.0, 6718.0, 107200.0, 6721.0, 14914.0, 19140.0, 8266.0, 25426.0, 725.0, 6869.0, 6237.0, 618.0, 6770.0, 6397.0] [ 6261  6696  6871   618  6870  6702  6289  4456  6682   620  6797  7175
#   1773 12455  6818  6399  6707  6914  6678   613]
#   0%|▎                                                                                  | 16/4976 [00:00<01:45, 46.83it/s]
# [15136.0, 29633.0, 388.0, 36069.0, 3750.0, 7046.0, 7240.0, 22025.0, 1962.0, 7277.0, 2222.0, 14861.0, 43743.0, 3828.0, 11220.0, 7286.0, 3482.0, 7167.0] [6999 3574 7308 7007  595 6213 3951 3762 7144 7179 2083 7016 3909 3949
#  7038 9885 7245 7077 3662    1]
# [10561.0, 7559.0, 8167.0, 6474.0, 5964.0, 36652.0, 2927.0, 7314.0, 169756.0, 36829.0, 26111.0] [ 583 3795 6371 7532  457 7466 4244 7350 4020 7316 7480 7423 7469 5955
#  7490 7559 7478 3047 7474 7500]
# [4356.0, 4619.0, 4623.0, 5135.0, 4625.0, 12690.0, 4627.0, 6677.0, 4631.0, 11799.0, 4634.0, 4635.0, 4637.0, 6814.0, 12702.0, 8097.0, 4646.0, 4648.0, 202792.0, 4654.0, 4656.0, 7601.0, 7602.0, 7603.0, 7604.0, 7605.0, 4663.0, 7607.0, 7614.0, 72953.0, 43211.0, 12759.0, 4313.0, 3803.0, 4067.0, 26085.0, 47333.0, 18664.0, 2665.0, 8299.0, 26091.0, 878.0, 6384.0, 8816.0, 2674.0, 8817.0, 29812.0, 9081.0, 8445.0, 49918.0] [5345  688 7563 7600 7612 7613 6221 7599 7614 6603 6438 7616 8822 7225
#  2071 7590  676 7591 7231 8097]
# [4482.0, 15394.0, 23912.0, 11851.0, 25261.0, 8049.0, 116597.0, 35769.0, 61564.0, 7966.0] [7707 3753 7678 2744 7822 7769 7706 7763 7762 7642 2593 7648 7638 4256
#  4794 7902 7766 4475 7641 6225]
# [47680.0, 2849.0, 10796.0, 8177.0, 2898.0, 8178.0, 61010.0, 77365.0, 10614.0, 34586.0] [3047 3968 4020 3569 7480  460  457 3714 3884 3725  480  583 3195 3718
#  3776 7136 1825 4740 4739 4738]
# [2328.0, 9925.0] [8405 5795  314 8454 8267 1697 4741 1447 6603 6213 8387 8538 8299 3827
#  1773 3725 8550 8543 8486 6084]
# [8704.0, 8705.0, 4482.0, 8450.0, 2820.0, 8706.0, 8707.0, 8708.0, 3976.0, 8709.0, 6282.0, 13579.0, 8718.0, 8719.0, 2704.0, 8720.0, 8722.0, 3350.0, 3611.0, 412.0, 152350.0, 4767.0, 3493.0, 3367.0, 2863.0, 38836.0, 3254.0, 6968.0, 8633.0, 8636.0, 1599.0, 13887.0, 5057.0, 8642.0, 3523.0, 8643.0, 453.0, 32064.0, 8647.0, 2898.0, 8788.0, 8661.0, 8662.0, 3415.0, 3291.0, 8670.0, 5089.0, 8673.0, 131564.0, 1776.0, 4083.0, 8691.0, 15221.0, 1656.0, 21625.0, 8698.0] [ 571 3725 1773 1447  470 1689 6603 2916 3152 1719  448 2045  449 3939
#  4741 3722 2083 8267  426  568]
# [22252.0] [ 3888 15384  6767  5952  8450   511  2388 17208 60520   618  3611  8438
#   7799   470 39257 54951 11767  6213  6217 19318]
# [8707.0, 8963.0, 8964.0, 8965.0, 8966.0, 4104.0, 8967.0, 8968.0, 3723.0, 7052.0, 397.0, 3342.0, 8969.0, 2704.0, 8970.0, 8971.0, 8975.0, 8976.0, 8977.0, 3350.0, 8978.0, 1944.0, 3356.0, 412.0, 7327.0, 9505.0, 6434.0, 31019.0, 1971.0, 6325.0, 3766.0, 3770.0, 699.0, 6079.0, 6907.0, 8644.0, 6214.0, 3661.0, 8910.0, 7120.0, 8788.0, 470.0, 8791.0, 5596.0, 8541.0, 8415.0, 4066.0, 2403.0, 2916.0, 30950.0, 2921.0, 4076.0, 7020.0, 2286.0, 39535.0, 8946.0, 8948.0, 8949.0, 4087.0, 3195.0, 4733.0, 6142.0] [6079 3725 6068 4741 1825 3884  470 6214 6213  476 1715 2286 3722 6907
#  8815 1969 2074  568  397 6069]
# [6913.0, 4.0, 388.0, 390.0, 9095.0, 264.0, 9224.0, 9225.0, 9092.0, 9228.0, 9227.0, 9232.0, 6289.0, 9087.0, 28.0, 2590.0, 671.0, 10615.0, 105249.0, 11809.0, 9254.0, 41.0, 9258.0, 9259.0, 5804.0, 9132.0, 9134.0, 9135.0, 117680.0, 9263.0, 6322.0, 9139.0, 5427.0, 1078.0, 9144.0, 9403.0, 301757.0, 7232.0, 194.0, 88773.0, 709.0, 83399.0, 9157.0, 26314.0, 9421.0, 9301.0, 9302.0, 9303.0, 600.0, 9177.0, 2396.0, 37086.0, 9208.0, 230.0, 6503.0, 9192.0, 30954.0, 2924.0, 9198.0, 2542.0, 9202.0, 5492.0, 9205.0, 9206.0, 9207.0, 7157.0, 9209.0, 22005.0, 9340.0, 5503.0] [ 9263  9264  6218  5794  9266  9267  6512  7309  2950  9262  9268  6503
#      3  2702  7590 40657  9421  1203  6463 14003]
#   1%|▍                                                                                  | 27/4976 [00:00<01:37, 50.86it/s]
# [448.0, 449.0, 3968.0, 3047.0, 9642.0, 267.0, 9643.0, 9645.0, 6609.0, 9617.0, 9618.0, 9620.0] [  267  6609   174  6608  6625  6606  6607   314   391  7198 13685  5795
#     16 13684  6610 26675    95 20903  6217 20904]
# [10113.0, 67846.0, 10121.0, 9995.0, 9997.0, 29581.0, 7439.0, 10127.0, 224273.0, 29587.0, 10133.0, 22.0, 10140.0, 6301.0, 38812.0, 10143.0, 10145.0, 6307.0, 10148.0, 9513.0, 13994.0, 14506.0, 53417.0, 162605.0, 3503.0, 7857.0, 9265.0, 7219.0, 51765.0, 19639.0, 2233.0, 13759.0, 22466.0, 9924.0, 40772.0, 68295.0, 6216.0, 9803.0, 35915.0, 69070.0, 7521.0, 7522.0, 73449.0, 9834.0, 10092.0, 76538.0, 14590.0] [6079 5772 1615 4740 8908 1825  568 1969 5108  595 8431 5302 7249 9446
#  8838 3195 3764 9932 6136   56]
# [98953.0, 4106.0, 3595.0, 5258.0, 3610.0, 2849.0, 10279.0, 10280.0, 10281.0, 10419.0, 10421.0, 10422.0, 10296.0, 287166.0, 10567.0, 10315.0, 10461.0, 2784.0, 10468.0, 10600.0, 142572.0, 142573.0, 4083.0, 4085.0, 10488.0, 10363.0, 10364.0, 10365.0, 10366.0] [ 2784  9772  4106  2849  3595 13823 10300  3968  3367 10367 10401  3076
#  10311 10343 10488  4063 10388 10335 10301 10323]
# [10759.0, 10765.0, 31630.0, 31631.0, 40340.0, 31666.0, 10675.0, 31539.0, 10679.0, 10936.0, 18747.0, 18766.0, 107983.0, 77393.0, 77395.0, 86233.0, 126817.0, 10731.0, 10738.0, 10739.0, 10740.0, 10741.0, 31735.0] [  571  1773  3725   470  3191   448  1447  1689  3152  3103  1719  2916
#   2045  2927  6603  4741  8846 10773   449  3169]
# [11145.0, 2316.0, 11151.0, 11152.0, 11026.0, 11154.0, 11028.0, 11029.0, 11155.0, 11161.0, 11037.0, 62238.0, 3235.0, 11049.0, 46253.0, 11183.0, 688.0, 2996.0, 11189.0, 6455.0, 1592.0, 43064.0, 92218.0, 2364.0, 8639.0, 22976.0, 3274.0, 11212.0, 11213.0, 11094.0, 11102.0, 101604.0, 6631.0, 6251.0, 11118.0, 11126.0] [ 3884  1773  3913  3873  8957  6212  6986  3939   470  3662  3951 11229
#   3153  3613   477  3633  1962  1578  7198   593]
# [26336.0, 11297.0, 11298.0, 10147.0, 172549.0, 28029.0, 6894.0, 12989.0, 7423.0] [7126 2299 2074 2077 6214 1715  568 6088 6068 8509 1835 2282  476 1578
#  6212 1449 1615 1687    1 8931]
# [7392.0, 195362.0, 330372.0, 4264.0, 18856.0, 81451.0, 29037.0, 159631.0, 137910.0, 5047.0, 11676.0] [ 6072  3688 11682 11605 11544  7951  5079  6078 11567 11494 11683 11589
#   7349  7360  8111  4161  2575 11563 11697 11582]
# [12294.0, 60938.0, 4112.0, 12307.0, 33818.0, 12316.0, 11805.0, 2590.0, 12317.0, 11825.0, 109619.0, 12341.0, 11831.0, 59.0, 12351.0, 12353.0, 12355.0, 12356.0, 12357.0, 12361.0, 12363.0, 12365.0, 11856.0, 11860.0, 8792.0, 8804.0, 3688.0, 8828.0, 62077.0, 217728.0, 3714.0, 11909.0, 12424.0, 11918.0, 11920.0, 11935.0, 11937.0, 11955.0, 11958.0, 11960.0, 11965.0, 71363.0, 5830.0, 12508.0, 12002.0, 40676.0, 12016.0, 12531.0, 12020.0, 12021.0, 246.0, 759.0, 5881.0, 9469.0, 12554.0, 6929.0, 5909.0, 78103.0, 8479.0, 12063.0, 12577.0, 29984.0, 12067.0, 12069.0, 12075.0, 12078.0, 2863.0, 12081.0, 7476.0, 12615.0, 118600.0, 142152.0, 2391.0, 12631.0, 12122.0, 864.0, 2916.0, 12133.0, 12134.0, 12652.0, 6512.0, 12147.0, 9087.0, 388.0, 12170.0, 12173.0, 7566.0, 12178.0, 916.0, 12180.0, 12184.0, 9113.0, 12186.0, 12197.0, 12203.0, 12204.0, 100779.0, 12207.0, 11713.0, 12233.0, 12235.0, 12241.0, 12243.0, 12248.0, 12250.0, 75738.0, 12263.0, 1012.0, 12280.0, 96250.0, 1022.0] [  304  5881 12455  6904  6289 12457  2803   177 12292  3782 12147   230
#  12384 11288 12575  6229 12574  2773  2582    94]
# [11779.0, 6283.0, 238479.0, 12176.0, 12712.0, 12720.0, 7601.0, 12735.0, 12736.0, 12746.0, 12747.0, 12748.0, 12749.0, 12750.0, 12752.0, 12753.0, 2391.0, 2274.0, 12770.0, 12261.0, 359.0, 12782.0, 12783.0] [12712  2274 12261  3803  7601 12783 12782 12743  4313 50381  4619 12770
#   8211 20137  4076 21370   426 18323 12755  8572]
# [12940.0, 12817.0, 2195.0, 12820.0, 12829.0, 12835.0, 12844.0, 12846.0, 9906.0, 10039.0, 12856.0, 696.0, 12860.0, 12864.0, 12865.0, 726.0, 12269.0, 12912.0, 248.0] [  304  2863   248   350   359  9866  3028  2390   388  6218  5678  1514
#   5772  2916   112  6463  6767 12907  5830 13675]
# [24778.0] [  6218 121327  32750  66618  21229  40293  22029   4122   8340  67291
#    7301  30520  26076  12982   9064   4436   2587  12466  15080  67277]
#   1%|▌                                                                                  | 33/4976 [00:00<01:55, 42.68it/s]
# [13056.0, 4232.0, 4105.0, 13066.0, 13069.0, 13070.0, 12436.0, 13077.0, 13078.0, 13207.0, 13208.0, 13210.0, 13084.0, 12189.0, 10655.0, 288.0, 8233.0, 6710.0, 12985.0, 2619.0, 2875.0, 12988.0, 12989.0, 12991.0, 3009.0, 12996.0, 12997.0, 12999.0, 13000.0, 13001.0, 202.0, 15819.0, 13005.0, 13007.0, 13137.0, 13138.0, 2899.0, 13012.0, 3157.0, 8790.0, 13140.0, 31442.0, 13146.0, 13023.0, 13151.0, 2401.0, 13026.0, 13153.0, 13154.0, 55799.0, 8955.0, 13053.0] [ 5881  2401 10610 13139  6225 13208  2899 11840 13137  2619 13146 12189
#  11930 18217 13138 13154 13140 13152 12637 13151]
# [3584.0, 10116.0, 2826.0, 13451.0, 7564.0, 15119.0, 12562.0, 13336.0, 5915.0, 5278.0, 1825.0, 13346.0, 7851.0, 40364.0, 8748.0, 6960.0, 6198.0, 9911.0, 568.0, 6462.0, 24130.0, 18251.0, 1996.0, 8268.0, 4192.0, 3823.0, 13553.0, 13555.0, 3574.0, 7032.0, 13432.0, 2813.0, 4479.0] [3611 7308 1969 7249 7118 6217 5524 5678 6213 7198   56 6069 6079  589
#  1615 6216 5498 5795 8759  568]
# [3939.0, 7236.0, 18280.0, 15050.0, 1773.0, 19952.0, 10201.0, 9113.0, 3291.0, 5948.0, 2334.0, 77407.0] [  6455   6221  19048    314   3611    470 106237   1773   6213   8405
#    7198   5795  12516   8454     95   3725   4553   1969   8745    583]
# [267.0] [ 1773    95  9642  6602   571  8219 14055 14027  6215 14058  8072   362
#    267   337  8193   228   174 13083  3004 14028]
# [23963.0, 1468.0, 2045.0] [ 2045  1689 14175  1719   571  8267   449  3191  3167   426 14184  2262
#   5056  3798 10963  1514  3186  3646  5410  3152]
# [221190.0, 10759.0, 180022.0, 31753.0, 211467.0, 5645.0, 262669.0, 10769.0, 180024.0, 77334.0, 64537.0, 180026.0, 193564.0, 7198.0, 3103.0, 3105.0, 34338.0, 180027.0, 3108.0, 10794.0, 555.0, 60971.0, 77868.0, 180029.0, 34351.0, 10800.0, 77872.0, 181804.0, 10803.0, 10804.0, 10805.0, 77877.0, 193582.0, 10808.0, 34362.0, 7227.0, 10812.0, 181820.0, 60990.0, 77887.0, 77888.0, 10817.0, 75842.0, 193598.0, 242748.0, 6213.0, 242750.0, 242751.0, 10824.0, 3145.0, 242753.0, 41548.0, 3149.0, 131148.0, 35920.0, 10835.0, 10836.0, 10837.0, 10838.0, 77395.0, 77398.0, 77399.0, 102997.0, 10843.0, 181850.0, 181851.0, 10846.0, 34399.0, 77408.0, 77918.0, 3170.0, 77920.0, 77921.0, 181858.0, 173672.0, 91241.0, 41579.0, 173676.0, 41581.0, 41582.0, 173678.0, 245879.0, 36472.0, 14461.0, 291967.0, 77441.0, 102529.0, 10884.0, 41604.0, 10887.0, 16017.0, 10901.0, 77465.0, 10912.0, 10915.0, 77476.0, 5798.0, 106151.0, 10920.0, 77487.0, 34480.0, 237233.0, 10930.0, 1715.0, 3764.0, 209077.0, 242356.0, 72889.0, 34490.0, 209081.0, 237244.0, 72906.0, 8396.0, 113358.0, 8399.0, 14543.0, 113361.0, 77522.0, 86233.0, 9968.0, 77558.0, 77559.0, 77560.0, 55550.0, 338697.0, 113930.0, 77584.0, 113938.0, 113940.0, 34581.0, 179995.0, 55582.0, 179999.0, 295713.0, 180002.0, 180003.0, 21288.0, 21289.0, 55592.0, 180010.0, 180013.0, 55598.0, 14639.0, 14640.0, 14641.0, 14642.0, 3379.0, 21300.0, 21301.0, 14644.0, 126768.0, 126772.0, 14649.0, 14650.0, 14651.0, 14652.0, 14653.0, 31548.0, 77625.0, 77628.0, 14657.0, 3394.0, 14658.0, 55617.0, 14661.0, 55619.0, 113984.0, 113985.0, 180034.0, 180041.0, 295746.0, 126286.0, 2899.0, 212819.0, 31573.0, 55639.0, 212831.0, 55657.0, 176490.0, 212843.0, 212849.0, 79734.0, 135034.0, 14206.0, 77183.0, 108927.0, 126773.0, 14213.0, 77189.0, 176517.0, 90504.0, 90508.0, 90512.0, 14227.0, 126269.0, 77221.0, 14251.0, 1969.0, 257461.0, 191417.0, 257469.0, 191422.0, 257471.0, 222656.0, 135108.0, 148943.0, 52694.0, 14295.0, 138199.0, 14297.0, 14303.0, 14304.0, 31711.0, 180014.0, 3558.0, 74218.0, 180017.0, 52723.0, 14325.0, 14328.0, 180019.0, 14333.0, 180020.0] [  589  6213  6069  6079 14027  1969  7198  4741  1715   593  6382  8937
#   6218  5678    39  6434    16  6068  4740  7250]
# [3328.0, 3648.0, 15394.0, 3299.0, 27042.0, 3336.0, 3345.0, 3380.0, 21148.0, 3295.0] [3718 3311 5596 3291 3680 3714 2772 2936 5948 3611 3725 8199 3679 7707
#   470 2717 2744 4081 2357 2788]
# [7043.0, 15619.0, 15628.0, 15504.0, 8209.0, 2581.0, 10648.0, 15642.0, 15649.0, 79651.0, 53937.0, 89913.0, 219974.0, 15700.0, 15839.0, 362.0, 15855.0, 15856.0, 237937.0, 15741.0] [13083    95  2875   337 14055 15515  2742  7043 15683 15684  9642  8221
#    339 15649 15700  2600   228 15633  8186  8214]
# [8832.0, 3207.0, 10759.0, 3341.0, 13968.0, 8978.0, 14227.0, 10772.0, 14357.0, 3350.0, 10778.0, 3103.0, 3368.0, 555.0, 49.0, 1715.0, 3379.0, 3253.0, 3509.0, 14265.0, 10810.0, 106700.0, 2254.0, 3538.0, 3283.0, 10835.0, 8793.0, 3291.0, 3676.0, 350.0, 3167.0, 3296.0, 2147.0, 3683.0, 1774.0, 2161.0, 8946.0, 14706.0, 3319.0, 9592.0, 3706.0, 2939.0] [8745 6079 5795 3611  350 5794 6213 1969  248 4741   16 5678 2916 6069
#  9866 6216 8368  314 6217 7030]
#   1%|▋                                                                                  | 44/4976 [00:00<01:44, 47.21it/s]
# [2863.0] [  593  4081   589  3185 14027  6088  5387  6215  1969  6079  3195   583
#   8765 13791  4266     1  4740 16239  7198  8768]
# [71973.0, 73640.0, 145900.0, 7533.0, 219758.0, 9775.0, 101167.0, 121200.0, 30996.0, 83199.0] [14024  3047  8751  7480  3195  8348  3646 16361 16428 16429 16398  3016
#   6091  2996   314  2433 16431  4192 16642  3929]
# [13441.0, 16907.0, 17037.0, 17805.0, 17044.0, 21529.0, 103710.0, 17055.0, 82467.0, 11812.0, 50981.0, 2857.0, 23850.0, 103337.0, 5556.0, 25401.0, 16955.0, 16956.0, 16957.0, 16958.0, 16959.0, 17089.0, 59463.0, 9417.0, 3658.0, 8011.0, 17100.0, 19787.0, 44236.0, 19791.0, 150479.0, 5202.0, 4446.0, 47336.0, 17006.0, 32241.0, 5747.0, 10484.0, 4213.0, 4215.0, 15352.0, 11642.0] [ 3643  2744  4256  3782  4180  3586 12458  7707  4374  7851  7802  4553
#   8347  5410  4794 17147  2357  4182  2647  4550]
# [18816.0, 3586.0, 4098.0, 644.0, 3076.0, 6276.0, 7565.0, 4112.0, 2833.0, 25361.0, 6035.0, 3860.0, 5910.0, 4249.0, 5020.0, 6301.0, 6303.0, 17824.0, 11938.0, 3619.0, 28454.0, 8487.0, 54311.0, 184701.0, 26283.0, 40368.0, 8629.0, 14903.0, 17335.0, 39482.0, 4283.0, 5308.0, 4161.0, 26690.0, 4292.0, 23494.0, 23497.0, 4428.0, 16972.0, 8404.0, 23384.0, 139736.0, 3803.0, 37851.0, 7392.0, 19808.0, 4322.0, 26080.0, 13412.0, 22884.0, 31588.0, 5352.0, 6122.0, 5740.0, 5617.0, 18289.0, 169204.0, 50295.0, 12285.0, 3583.0] [ 2927  4110  6365  4231  3688  4264  4085  3803  2898 11494  4063  5079
#   4159  3814  1724  6907  6913  4080 10561  7708]
# [13281.0, 9475.0, 12847.0, 9424.0, 11892.0, 12916.0, 18135.0, 18072.0, 9499.0, 18078.0, 17919.0] [  470  3725  3968  1773  3047  2916   457  3776  3714  4020  4741  3611
#   4737 12455  7190  3888  4738  1169   460  1447]
# [13003.0, 18204.0, 58853.0, 91063.0] [13048 18217 18205  2854 18212  2443 18216 13210  2572 18215 18191 18192
#  18209 18213 18228  5564 18246 18236 18240 18243]
# [39653.0, 21767.0, 47466.0, 5387.0, 97451.0, 84717.0, 18257.0, 15154.0, 13810.0, 13876.0, 26453.0, 108599.0] [5387 1615 6079 9527  568 3611 1969 1825 6088  457 4299  589 9861 6216
#  6069 3646 3680 3195 2074 4740]
# [18562.0, 7043.0, 189447.0, 136075.0, 15500.0, 68756.0, 18712.0, 18713.0, 18714.0, 18715.0, 13083.0, 18716.0, 18717.0, 18718.0, 18719.0, 18720.0, 18721.0, 18722.0, 14132.0, 23352.0, 5433.0, 6602.0, 35405.0, 79.0, 217.0, 50399.0, 14057.0, 362.0, 15595.0, 89718.0, 23417.0, 90234.0] [   95  6881 18555  5345   479  6309 22653   688 15148  7612  2700  7613
#   3782  6218   583   680 10617  8206 44952  6512]
# [8832.0, 106241.0, 37379.0, 18823.0, 16.0, 150.0, 3611.0, 283.0, 8480.0, 18849.0, 5795.0, 132259.0, 7851.0, 12589.0, 12590.0, 17839.0, 18861.0, 18866.0, 11958.0, 85304.0, 6076.0, 15548.0, 193087.0, 194.0, 196.0, 8389.0, 18886.0, 78663.0, 93898.0, 18892.0, 18893.0, 18904.0, 18914.0, 18916.0, 18918.0, 18921.0, 1514.0, 18922.0, 8688.0, 8950.0, 12027.0, 380.0, 179453.0, 18814.0] [12589  8688  9866  6448   248    22  3291  6217     5  8745   357   194
#    331   350   229  5830  2644 16023    55  7851]
# [19074.0, 19075.0, 19078.0, 19143.0, 712.0, 122087.0, 6922.0, 19018.0, 19020.0, 6797.0, 19021.0, 19023.0, 19030.0, 142299.0, 19070.0] [ 8266  6801  6289  2744  6225  3782  1773  7569  6428 12455  6680  6255
#   6881  6229  7175  6446  4553   680  6684   618]
#   1%|▉                                                                                  | 55/4976 [00:01<01:59, 41.33it/s]
# [5888.0, 8197.0, 67269.0, 14823.0, 19562.0, 19627.0, 23404.0, 589.0, 13902.0, 35275.0, 4018.0, 19511.0, 12886.0, 5623.0, 19608.0, 19545.0, 3803.0] [  457  3611   583   589  3968  2370  4740  3725 13791  5807  6216  5387
#   6079   479  6213  4251  4741  8210  1969  4266]
# [10631.0, 99335.0, 3978.0, 22539.0, 19861.0, 19862.0, 19863.0, 19864.0, 19736.0, 19742.0, 19232.0, 3874.0, 40996.0, 3882.0, 36406.0, 44086.0, 19265.0, 14151.0, 14153.0, 46555.0] [ 5596  3718  3680  3679  2772  2936  3913 11096  3721  3873  3311  5560
#   3616  2939  3348  3884  3203   470  3153  3939]
# [8385.0, 94026.0, 19885.0, 8400.0, 109331.0, 7452.0, 30747.0, 12508.0] [19996  9612  3750 12637 11096  1773  4075 47239  4089  8869  5104  2926
#   9081 18286  6221  7245 10404 13793 33818  3047]
# [10400.0, 45368.0, 8547.0, 44036.0, 19656.0, 20201.0, 273998.0, 4242.0, 67730.0, 4533.0, 6070.0, 10422.0, 26293.0, 20346.0, 44636.0] [ 3714 26339   211 30188 23366 10648  3047 11984 10558 41356 14003 26542
#  15379  3344  8185 13905  5884 53699 12590 33316]
# [20480.0, 53505.0, 20482.0, 7427.0, 2316.0, 20492.0, 4112.0, 20497.0, 134801.0, 184470.0, 18043.0, 3869.0, 29349.0, 7851.0, 20398.0, 3632.0, 72626.0, 31735.0, 16312.0, 13882.0, 10176.0, 3649.0, 31681.0, 10179.0, 8644.0, 84547.0, 184520.0, 20429.0, 109261.0, 4053.0, 7382.0, 11607.0, 20438.0, 9945.0, 8797.0, 15070.0, 20453.0, 66921.0, 75370.0, 20460.0, 56950.0, 20471.0, 20473.0, 8443.0, 20476.0, 4095.0] [ 3888   511  3643 12458  4256  7799 17208  7802 15384  8347  2744 60520
#   7851 11096 16976  5952  8438  4374  6767  3586]
# [256.0, 20866.0, 20995.0, 389.0, 20998.0, 154122.0, 20769.0, 20905.0, 20908.0, 15663.0, 5425.0, 294593.0, 89799.0, 20943.0, 94806.0, 5590.0, 20952.0, 262107.0, 20716.0, 20859.0, 16637.0, 20863.0] [ 6215  6625  6606    38   173  6608 13684  2682  5421   174 13685  3004
#   6602    55 35828  6607  2608  6609  5423    84]
# [45570.0, 3971.0, 41095.0, 3850.0, 10380.0, 47377.0, 52883.0, 3733.0, 22172.0, 10397.0, 56224.0, 7714.0, 10542.0, 218551.0, 98621.0, 2246.0, 1864.0, 2248.0, 30411.0, 37195.0, 56779.0, 34513.0, 41041.0, 4061.0, 59888.0, 7678.0] [5596 3718  583 5807   95 3680 3311 4081 2772 3721 2936 5889 3714 4244
#  2858 3153 3291 3725  412 2860]
# [8451.0, 60164.0, 8199.0, 21512.0, 21389.0, 7569.0, 4245.0, 2587.0, 21406.0, 14239.0, 21409.0, 7714.0, 2469.0, 13226.0, 19629.0, 32046.0, 141614.0, 2480.0, 12720.0, 8883.0, 21427.0, 2614.0, 3767.0, 21431.0, 7231.0, 9411.0, 18758.0, 15947.0, 28875.0, 21334.0, 21595.0, 7388.0, 5860.0, 21477.0, 2919.0, 3308.0, 5996.0, 15981.0, 61424.0, 3327.0] [2587 3291 5948  248 7707 3311 2944 5410 3714 5289 2717 8199 3718  350
#  2744 5596 3803 2788 3503 2418]
# [21639.0, 1931.0, 9740.0, 21657.0, 21658.0, 8219.0, 21661.0, 21662.0, 5919.0, 259360.0, 1575.0, 167.0, 8361.0, 21418.0, 5678.0, 5295.0, 14130.0, 5811.0, 9655.0, 6084.0, 14022.0, 8264.0, 6602.0, 10571.0, 1618.0, 5207.0, 5214.0, 21623.0, 21610.0, 21611.0, 21613.0, 21614.0, 8815.0, 21616.0, 21617.0, 21744.0, 21745.0, 9844.0, 1781.0, 9589.0, 3319.0, 21620.0, 21621.0, 21622.0, 21624.0] [  167  8219  8264  6084  6327 14022 14130  8454  8210   314 21744  6602
#  21659  7198   137  5295 10647  3714   475  5795]
#   1%|█                                                                                  | 66/4976 [00:01<01:46, 46.29it/s]
# [43623.0, 18351.0, 2103.0, 24985.0, 8543.0] [ 3913  3873  3616  6213  3718  3662  8957  1969  3884   593   477  2083
#   2316  3195  3203  3584 11096  6212  2076  3886]
# [2193.0, 2916.0, 2286.0] [4741 1630 6216 3611 4740  476 1715  480  478 6214    1  468  458 6213
#  1773  593  470 1969 6068 2916]
# [11873.0, 8838.0, 4299.0, 8848.0, 2641.0] [ 3611  3718  2641  3195  3951  3291  4299  5915  8838  3873  2703 11873
#   5772 10109  3878  4741  6216     1 19753   593]
# [8835.0, 5894.0, 20362.0, 55947.0, 1689.0, 17311.0, 226207.0, 3873.0, 14241.0, 1831.0, 7209.0, 29610.0, 38066.0, 6199.0, 5311.0, 9932.0, 8916.0, 601.0, 3558.0, 6129.0, 1784.0, 10105.0] [3152 3196  448 2916 1689 1697 5921 3725  451  426 1447 6324 1931  571
#  6325 4741 8323 3884 3188  593]
# [449.0, 4266.0, 8849.0, 15305.0] [3311 4081 4266 3725 2916 3153 3714 5596 2860  448 3152 3939 2772  571
#  1689 1773 8199 3167 2858 4105]
# [6401.0, 86156.0, 36629.0, 196761.0, 156829.0, 97700.0, 249899.0, 47031.0, 80831.0, 47040.0, 249926.0, 228809.0, 22733.0, 121170.0, 154579.0, 68180.0, 316263.0, 323827.0, 75126.0, 86135.0, 269304.0] [19411  6225  6218  2744  5860  6229 19111  6763  1730  6880 22729  6428
#  12455  6289 13184  5881 22630 22745  6801  6449]
# [3336.0, 22920.0, 82964.0, 2587.0, 3744.0, 9390.0, 2864.0, 5187.0, 5445.0, 5447.0, 457.0, 3798.0, 4441.0, 22877.0, 350.0, 8415.0, 22881.0, 22883.0, 22885.0] [  457  2863   350  9866  9411  3968  2700   331   248 22960  2864  3680
#   3195  3658  8751   357  4225  5478  4741  9412]
# [36610.0, 108163.0, 34184.0, 52105.0, 75786.0, 34187.0, 108298.0, 34189.0, 34318.0, 108427.0, 108176.0, 34193.0, 52113.0, 34196.0, 108308.0, 138138.0, 34204.0, 34205.0, 36381.0, 34207.0, 70052.0, 34213.0, 31782.0, 23032.0, 108456.0, 34602.0, 34219.0, 59186.0, 34233.0, 36284.0, 108222.0, 34369.0, 108230.0, 34375.0, 34250.0, 34378.0, 34381.0, 37581.0, 37582.0, 37583.0, 37584.0, 34260.0, 69076.0, 34262.0, 34391.0, 36439.0, 34265.0, 34267.0, 34271.0, 108383.0, 134752.0, 34274.0, 108136.0, 79726.0, 108398.0, 37489.0, 23030.0, 34168.0, 108284.0, 36605.0] [ 3195  3047  9940  3646  4299  4075 11096  2067  6091  2770  3680  6095
#   5953 16304  9861  3764  7480  4192  9938  4225]
# [7171.0, 23813.0, 23816.0, 3466.0, 2320.0, 3217.0, 2328.0, 13338.0, 20381.0, 3486.0, 3998.0, 10398.0, 12705.0, 27037.0, 71587.0, 3237.0, 29349.0, 38821.0, 3368.0, 3625.0, 22269.0, 3888.0, 23346.0, 3379.0, 3638.0, 3064.0, 3641.0, 3642.0, 3387.0, 3260.0, 10555.0, 3262.0, 3519.0, 240441.0, 453.0, 3269.0, 19783.0, 5064.0, 8649.0, 3661.0, 3918.0, 21966.0, 11090.0, 20691.0, 23762.0, 3285.0, 3286.0, 24659.0, 23768.0, 3676.0, 2141.0, 3679.0, 3296.0, 8801.0, 23778.0, 3939.0, 17124.0, 23807.0, 46311.0, 8569.0, 5994.0, 12525.0, 3694.0, 3311.0, 2288.0, 5102.0, 23792.0, 57327.0, 3701.0, 1784.0, 3705.0, 12538.0, 23803.0, 4093.0, 2942.0, 3967.0] [ 3888  6767   350   248  2388  2863  5772 15384  9866 17208  8450  7564
#   7245   511  8745  7799  5478  2864  5952   618]
# [2282.0, 7309.0] [ 540  470 4741 1773  583 3611 6069 3725 7826 2916  593  542 1447 1969
#   571 6213  476 6605 6084 3152]
# [14246.0, 23979.0, 23980.0, 14509.0, 23949.0, 14192.0, 5524.0, 23956.0, 23957.0, 23960.0, 22973.0, 23967.0] [ 5524  8076 14192  7308   568  1615  5915    56 13336  3016  4479  8973
#   5678 22881 13315   350  3060  8348  7118  7072]
#   2%|█▎                                                                                 | 78/4976 [00:01<01:36, 50.61it/s]
# [43906.0, 105736.0, 187145.0, 16658.0, 19617.0, 19499.0, 24370.0, 24372.0, 47285.0, 13390.0, 16465.0, 16214.0, 55898.0, 18279.0, 69486.0, 23667.0, 24313.0, 5370.0, 37118.0] [  589  2067  9861  2657  9938  2779  2915  2735   593 14027  2659  9950
#   2826  9862  5921  2216  3646  2691  2909 10806]
# [24481.0, 216646.0, 163984.0, 226994.0, 216595.0, 125236.0, 138069.0, 125243.0] [39924 11644  6191 11794 11793 19096 25097 11798  6450  4627 20006 29006
#  11795  8745 49921 44809 51301 11796 18525 75591]
# [230528.0, 3077.0, 112139.0, 14998.0, 98969.0, 198431.0, 44704.0, 7087.0, 75952.0, 56881.0, 104624.0, 38197.0, 63414.0, 13250.0, 131914.0, 104139.0, 19790.0, 15063.0, 27991.0, 130393.0, 212573.0, 62046.0, 343903.0, 104161.0, 25058.0, 25059.0, 25060.0, 59119.0, 4083.0, 76148.0, 59642.0, 123772.0, 303485.0] [ 2296  2288  6108 12458  2280 24840  3679  6112 22367 24531 12487  3716
#  15313  2086 24521 24494 24818 24979  2089  3559]
# [18049.0, 25223.0, 25224.0, 17036.0, 5773.0, 7695.0, 2833.0, 25237.0, 25365.0, 25366.0, 25240.0, 36894.0, 25249.0, 25378.0, 2851.0, 33058.0, 34174.0, 8870.0, 25126.0, 15402.0, 10669.0, 6447.0, 25135.0, 25286.0, 67655.0, 12232.0, 25170.0, 2390.0, 215.0, 861.0, 25185.0, 12516.0, 22628.0, 25190.0, 15343.0, 25071.0, 25072.0, 25073.0, 25081.0, 9210.0, 890.0] [  304  3028   388   112   359  2882  9089  2388  2881  2390   215  2884
#   2887  2391  3803 12359  9458 25240 12529  2883]
# [4224.0, 324993.0, 142658.0, 25957.0, 157515.0, 173710.0, 5679.0, 5135.0, 226958.0, 3608.0] [25585 19904 22033 25606  5679 25455 25594 25927 25724 25435 25644 25496
#  25488 25595 25561 25503 25638  4318 25909 25557]
# [25971.0, 26092.0] [  2744   7707  18664  23778    546   5410  44514  30274   9546 106241
#    7976   3347  15391      1   3303  22597  19411  21505   1969   3438]
# [26112.0, 59911.0, 26125.0, 19472.0, 26129.0, 26130.0, 26131.0, 52241.0, 5141.0, 98322.0, 278051.0, 117800.0, 59947.0, 26156.0, 117805.0, 52276.0, 52278.0, 89142.0, 86585.0, 39483.0, 5692.0, 105546.0, 11344.0, 26193.0, 11346.0, 11350.0, 11351.0, 125528.0, 11354.0, 26207.0, 42089.0, 26218.0, 195692.0, 26223.0, 25715.0, 52854.0, 52855.0, 10363.0, 28288.0, 6787.0, 27274.0, 24205.0, 25762.0, 25768.0, 91821.0, 211642.0, 18112.0, 103111.0, 79053.0, 91853.0, 19155.0, 4820.0, 51925.0, 4824.0, 8184.0, 159970.0, 96995.0, 3813.0, 47333.0, 18664.0, 159978.0, 49900.0, 6893.0, 223982.0, 50417.0, 49907.0, 26877.0, 97023.0, 27913.0, 292107.0, 219920.0, 31505.0, 7442.0, 40212.0, 67350.0, 100122.0, 31515.0, 31516.0, 19229.0, 52509.0, 100133.0, 28454.0, 97063.0, 52521.0, 97068.0, 100150.0, 5944.0, 52536.0, 4411.0, 157515.0, 5966.0, 100176.0, 5969.0, 14163.0, 34649.0, 18777.0, 57698.0, 97122.0, 5989.0, 100198.0, 25963.0, 100203.0, 5998.0, 29039.0, 6000.0, 136048.0, 292211.0, 76670.0, 27011.0, 244099.0, 6021.0, 25481.0, 92046.0, 5008.0, 7568.0, 7570.0, 6039.0, 26007.0, 226721.0, 113059.0, 7589.0, 93094.0, 61352.0, 26031.0, 95151.0, 28083.0, 33716.0, 26047.0, 21952.0, 26048.0, 26049.0, 26050.0, 26052.0, 17861.0, 50627.0, 100293.0, 93131.0, 192459.0, 26062.0, 67022.0, 104913.0, 59862.0, 65528.0, 104922.0, 26076.0, 104924.0, 112093.0, 17887.0, 38883.0, 25572.0, 26086.0, 26089.0, 26090.0, 26093.0, 26094.0, 26095.0, 26096.0, 26102.0, 26104.0, 26109.0, 26110.0, 26111.0] [ 6365  6313  4115  5947  6930  4254  5090  4260  4318  5995  6929 26279
#   1723 26092 18309  7566  4231  6274 17481  6906]
# [2947.0, 388.0, 5763.0, 17033.0, 26380.0, 13198.0, 26513.0, 98962.0, 5140.0, 2581.0, 26646.0, 26397.0, 47352.0, 9250.0, 11939.0, 26147.0, 4261.0, 26404.0, 7719.0, 26406.0, 47011.0, 26410.0, 10411.0, 174.0, 4527.0, 59312.0, 12082.0, 8883.0, 180.0, 309.0, 5814.0, 2615.0, 59316.0, 14139.0, 3004.0, 701.0, 31293.0, 109499.0, 2368.0, 120129.0, 218943.0, 2884.0, 47044.0, 146249.0, 22474.0, 147152.0, 21844.0, 31189.0, 3798.0, 3803.0, 13154.0, 28898.0, 24164.0, 5607.0, 17768.0, 8297.0, 25320.0, 36201.0, 51049.0, 75115.0, 4079.0, 5360.0, 13167.0, 46066.0, 13553.0, 15220.0, 5493.0, 10102.0, 46070.0, 1784.0, 121202.0, 11899.0] [  267   304   359  3028   388  4225  4192  9527  8785 15739  4247  2882
#   2651   174 25209 15148 26339  7719 26588  2388]
# [115715.0, 2916.0, 4740.0, 6084.0, 457.0, 3725.0, 304.0, 593.0, 6609.0] [6213 4741 3611 1773 3725 7198 5795 1969  593 6069 6079  470 1447  314
#  2916    1 6603 6216 4740 1630]
# [10400.0, 4259.0, 4068.0, 5541.0, 25158.0, 13575.0, 8264.0, 5356.0, 21744.0, 27411.0, 2900.0, 3157.0, 2901.0, 3768.0, 8219.0, 10525.0, 4063.0] [ 8219  4063  8264   457  3157  4068  2900  2901  4112  3768  4089  4259
#   4079  5356  5541  4117 13575 21744   383   385]
#   2%|█▍                                                                                 | 84/4976 [00:01<01:35, 51.16it/s]
# [5504.0, 4740.0, 4741.0, 9860.0, 8852.0, 5911.0, 2199.0, 27420.0, 415.0, 5678.0, 2223.0, 2735.0, 8885.0, 5302.0, 7351.0, 16568.0, 5948.0, 7110.0, 14279.0, 9805.0, 8916.0, 2657.0, 1514.0, 6382.0, 8827.0, 5500.0, 15997.0] [4741 1514 1773 2916 5772 4740 6434 1715 3725 3611  452 2364 1447  593
#   571 8832 8851 8908    1 6603]
# [306689.0, 78851.0, 27663.0, 27674.0, 27675.0, 27680.0, 10785.0, 28195.0, 27686.0, 28207.0, 40500.0, 10806.0, 187446.0, 27714.0, 27717.0, 28230.0, 27720.0, 28233.0, 28234.0, 28236.0, 27727.0, 27729.0, 2649.0, 27737.0, 64605.0, 64606.0, 27748.0, 27749.0, 27753.0, 38000.0, 347764.0, 143989.0, 28282.0, 63098.0, 28285.0, 28288.0, 27777.0, 27778.0, 28289.0, 28290.0, 28291.0, 9862.0, 28295.0, 28300.0, 27789.0, 24718.0, 27791.0, 28302.0, 27794.0, 28307.0, 28309.0, 11419.0, 9884.0, 54427.0, 80027.0, 149150.0, 9888.0, 28329.0, 28332.0, 11438.0, 9903.0, 28334.0, 28340.0, 194230.0, 149186.0, 28356.0, 27852.0, 211812.0, 2770.0, 27860.0, 9945.0, 28378.0, 28381.0, 27888.0, 28401.0, 28407.0, 27898.0, 28412.0, 27902.0, 193280.0, 28426.0, 116490.0, 28428.0, 28433.0, 28446.0, 22307.0, 4901.0, 28456.0, 28459.0, 27957.0, 56117.0, 28473.0, 18748.0, 28476.0, 28477.0, 49982.0, 10048.0, 28480.0, 28482.0, 56640.0, 74564.0, 28486.0, 176454.0, 28490.0, 35660.0, 28493.0, 28494.0, 24399.0, 27983.0, 28495.0, 28498.0, 27992.0, 36696.0, 27996.0, 27998.0, 48478.0, 28512.0, 28513.0, 23907.0, 28004.0, 28516.0, 28518.0, 28519.0, 36707.0, 5993.0, 10089.0, 28009.0, 28522.0, 22893.0, 28527.0, 28025.0, 28540.0, 28545.0, 28038.0, 28553.0, 28555.0, 163214.0, 36751.0, 28561.0, 9106.0, 28051.0, 28053.0, 28056.0, 135581.0, 27555.0, 27560.0, 19882.0, 8109.0, 28083.0, 180147.0, 28087.0, 349111.0, 174009.0, 27579.0, 170428.0, 56766.0, 36801.0, 27590.0, 27595.0, 114126.0, 16849.0, 122323.0, 27605.0, 31703.0, 5592.0, 27608.0, 28123.0, 26077.0, 45022.0, 143844.0, 56807.0, 68073.0, 27633.0, 27636.0, 28149.0, 27640.0, 28158.0, 37887.0] [ 2915  2067  9938  7822  9862  2659  9892  2657 10754 10806  2649 15046
#   2909  9888 18747 10796 21967 22224 10785 36707]
# [28672.0, 28673.0, 28674.0, 28675.0, 28676.0, 22790.0, 18569.0, 6289.0, 28694.0, 791.0, 6295.0, 1184.0, 6433.0, 683.0, 6319.0, 6709.0, 18635.0, 22865.0, 734.0, 28662.0, 28670.0, 1151.0] [22554  6289  6914  6428  1731  6871 19411  6675 18555  1726  6702 11913
#   6680  1730  6801  6399  6261  6446   680  6449]
# [28800.0, 18055.0, 7048.0, 11150.0, 28815.0, 7058.0, 11283.0, 28819.0, 28828.0, 9885.0, 1574.0, 1837.0, 6965.0, 6213.0, 6985.0, 18377.0, 22226.0, 3291.0, 7006.0, 28784.0, 1654.0, 7164.0] [ 6212  3185  8405  8454  1574  1624  1962  8387  1697  6672  6463  7147
#   8512  8574   593 11150  7144  7094  7198  1653]
# [16035.0, 388.0, 96323.0, 40360.0, 8745.0, 83402.0, 95947.0, 61776.0, 220560.0, 371.0, 147517.0, 15957.0, 13781.0, 99511.0, 16056.0, 213782.0, 137499.0, 23933.0] [ 4081 16954  6904 29004  6362  4266 28986 11798 25114  6931 12529  9089
#   6279 12725 22552 28957 21529   694  6239 29013]
# [6785.0, 3714.0, 19336.0, 42248.0, 43272.0, 172044.0, 29197.0, 197774.0, 214668.0, 169235.0, 169236.0, 71829.0, 23064.0, 19355.0, 67873.0, 155427.0, 127653.0, 64552.0, 80297.0, 19125.0, 67895.0, 29117.0, 6846.0, 29247.0, 7104.0, 29248.0, 122685.0, 2500.0, 11076.0, 29257.0, 11082.0, 170060.0, 111053.0, 29264.0, 50512.0, 10963.0, 29139.0, 8534.0, 29270.0, 107100.0, 11229.0, 67169.0, 77026.0, 110719.0, 111081.0, 27504.0, 110706.0, 112498.0, 10740.0, 29173.0, 47862.0, 47863.0, 47864.0, 47865.0, 47866.0, 50296.0, 29309.0, 67967.0] [ 1773  6675  6261 11145  6678  8548  6702 11139  8454 11082   571  6871
#   6986  6289   470  1697  8761  6914  6900  1574]
# [5606.0, 22887.0, 14248.0, 6217.0, 6218.0, 12767.0, 29478.0, 17327.0, 29521.0, 29522.0, 29523.0, 29527.0, 10872.0, 29466.0, 23003.0, 29469.0, 5343.0] [ 5498     3 10620  8759    16  8745 15751 10616  5753  5678  6213   176
#   6079  6217  8748   248  2826  5878  7249  9866]
# [14208.0, 29569.0, 108936.0, 19081.0, 5772.0, 8332.0, 13335.0, 5659.0, 1823.0, 13343.0, 3617.0, 67753.0, 29612.0, 2223.0, 29617.0, 17970.0, 29622.0, 29624.0, 6457.0, 12475.0, 2364.0, 1468.0, 12733.0, 30016.0, 30657.0, 122696.0, 1994.0, 2000.0, 42196.0, 6743.0, 99160.0, 13404.0, 76125.0, 2274.0, 5986.0, 26467.0, 8812.0, 6382.0, 37751.0, 21748.0, 3191.0, 12922.0] [ 4741  8486     1  6434 10149  7563   593   476  1697  6213  3196  8573
#   6325  6627  3152  1512  6603 29572  3185  7206]
# [1029.0, 29704.0, 7177.0, 29706.0, 29707.0, 12300.0, 28684.0, 5135.0, 38417.0, 4627.0, 1045.0, 10261.0, 28693.0, 191515.0, 214044.0, 12832.0, 29733.0, 29738.0, 9771.0, 29745.0, 29749.0, 29751.0, 29753.0, 12859.0, 29757.0, 7231.0, 28736.0, 17986.0, 29762.0, 29763.0, 9285.0, 22085.0, 6215.0, 21576.0, 1609.0, 29769.0, 6221.0, 23125.0, 1624.0, 29785.0, 6237.0, 29790.0, 1631.0, 43618.0, 613.0, 29797.0, 29288.0, 6761.0, 6763.0, 7275.0, 8299.0, 29805.0, 29809.0, 39537.0, 93812.0, 7285.0, 39544.0, 29819.0, 640.0, 12929.0, 8322.0, 174218.0, 8333.0, 29837.0, 6289.0, 8339.0, 29844.0, 33939.0, 662.0, 29847.0, 1696.0, 6818.0, 21667.0, 29858.0, 6314.0, 29867.0, 684.0, 2222.0, 25267.0, 8377.0, 29883.0, 701.0, 29886.0, 29887.0, 1728.0, 13506.0, 29898.0, 29900.0, 50381.0, 29903.0, 29905.0, 29906.0, 8405.0, 9430.0, 12503.0, 18136.0, 22231.0, 23768.0, 29910.0, 29911.0, 29915.0, 29917.0, 29919.0, 9440.0, 43743.0, 77025.0, 29923.0, 29924.0, 29925.0, 29926.0, 29927.0, 85217.0, 745.0, 29929.0, 16107.0, 101612.0, 8433.0, 29937.0, 29938.0, 29939.0, 29941.0, 21238.0, 29942.0, 43761.0, 95989.0, 183033.0, 132350.0, 9472.0, 29954.0, 29957.0, 132364.0, 16141.0, 8981.0, 5911.0, 8984.0, 8476.0, 303395.0, 10026.0, 10539.0, 29998.0, 304.0, 30004.0, 9526.0, 12598.0, 367926.0, 30009.0, 6974.0, 30014.0, 112447.0, 30019.0, 8520.0, 30027.0, 7522.0, 868.0, 170854.0, 7021.0, 22896.0, 8562.0, 7027.0, 21370.0, 78232.0, 9627.0, 27548.0, 10141.0, 32669.0, 29599.0, 11682.0, 360354.0, 12708.0, 5546.0, 29614.0, 12719.0, 85435.0, 10173.0, 12223.0, 1472.0, 32707.0, 12741.0, 17862.0, 470.0, 142299.0, 1001.0, 9204.0, 29689.0] [ 6463  6767  8299  9081  7175  6221  7231   613   676   470  8574 11220
#   6218  7225  6912  8817  6812  2222  8405  6794]
# [384.0, 19714.0, 4.0, 390.0, 30471.0, 393.0, 30476.0, 30606.0, 9619.0, 213779.0, 112022.0, 663.0, 13336.0, 5789.0, 17446.0, 14250.0, 12589.0, 12590.0, 176.0, 52658.0, 5557.0, 15413.0, 3009.0, 194.0, 46918.0, 6217.0, 2640.0, 35792.0, 13268.0, 90.0, 475.0, 348.0, 21467.0, 30429.0, 30560.0, 80229.0, 230.0, 14190.0, 30463.0] [  267   174  6609   176  9866  6217   248 10758   350    84  5678  8745
#  30427   186   457  9411  6448   331 30519  2863]
# [8832.0, 19337.0, 23053.0, 6675.0, 7572.0, 25370.0, 21404.0, 85665.0, 39.0, 67880.0, 29746.0, 30642.0, 8500.0, 19380.0, 9782.0, 60088.0, 9536.0, 34762.0, 13772.0, 466.0, 1624.0, 13535.0, 11116.0, 9453.0, 240113.0, 6261.0, 2045.0] [   39  6261  1447  8832  1514  4741  2641   466   350   248  2916  3188
#   1773  3167  3152 29746  2045 23053   470  2222]
#   2%|█▍                                                                                 | 89/4976 [00:01<01:41, 47.95it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 26
#      24     user_row = None
#      25 else:
# ---> 26     user_row = user_item_matrix[uid_int]
#      27     is_new_user = (user_row.getnnz() == 0)  # нет интеракций в train
#      29 if is_new_user:
#      30     # cold start: рекомендуем топ-10 популярных
#
# File /opt/venv/lib/python3.11/site-packages/scipy/sparse/_index.py:64, in IndexMixin.__getitem__(self, key)
#      62     res = self._get_intXint(row, col)
#      63 elif isinstance(col, slice):
# ---> 64     res = self._get_intXslice(row, col)
#      65 elif col.ndim == 1:
#      66     res = self._get_intXarray(row, col)
#
# File /opt/venv/lib/python3.11/site-packages/scipy/sparse/_csr.py:228, in _csr_base._get_intXslice(self, row, col)
#     226 def _get_intXslice(self, row, col):
#     227     if col.step in (1, None):
# --> 228         return self._get_submatrix(row, col, copy=True)
#     229     # TODO: uncomment this once it's faster:
#     230     # return self._getrow(row)._minor_slice(col)
#     232     M, N = self.shape
#
# File /opt/venv/lib/python3.11/site-packages/scipy/sparse/_compressed.py:892, in _cs_matrix._get_submatrix(self, major, minor, copy)
#     890 if self.ndim == 1:
#     891     shape = (shape[1],)
# --> 892 return self.__class__((data, indices, indptr), shape=shape,
#     893                       dtype=self.dtype, copy=False)
#
# File /opt/venv/lib/python3.11/site-packages/scipy/sparse/_compressed.py:30, in _cs_matrix.__init__(self, arg1, shape, dtype, copy, maxprint)
#      29 def __init__(self, arg1, shape=None, dtype=None, copy=False, *, maxprint=None):
# ---> 30     _data_matrix.__init__(self, arg1, maxprint=maxprint)
#      32     if issparse(arg1):
#      33         if arg1.format == self.format and copy:
#
# File /opt/venv/lib/python3.11/site-packages/scipy/sparse/_data.py:21, in _data_matrix.__init__(self, arg1, maxprint)
#      20 class _data_matrix(_spbase):
# ---> 21     def __init__(self, arg1, *, maxprint=None):
#      22         _spbase.__init__(self, arg1, maxprint=maxprint)
#      24     @property
#      25     def dtype(self):
#
# KeyboardInterrupt:

# %%
import numpy as np
from tqdm import tqdm

K = 10          # финальный top-K
CAND_K = 200    # размер пула кандидатов для rerank

# --------------------------
# 1. Популярность и свежесть
# --------------------------
n_items = user_item_matrix.shape[1]

# Популярность: сколько раз трек встречается в train
item_popularity = np.asarray(user_item_matrix.sum(axis=0)).ravel()

# Нормируем к [0, 1]
pop_min, pop_max = item_popularity.min(), item_popularity.max()
pop_norm = (item_popularity - pop_min) / (pop_max - pop_min + 1e-8)

# Свежесть: берем последний timestamp для каждого item из train-данных
# здесь "train_df" — датафрейм с колонками ["uid", "item_id", "timestamp"]
item_last_ts = train_df.groupby("item_id")["timestamp"].max()

# приводим к массиву длины n_items (если item_id идут с 0 до n_items-1)
item_last_ts = item_last_ts.reindex(range(n_items), fill_value=item_last_ts.min()).to_numpy()

ts_min, ts_max = item_last_ts.min(), item_last_ts.max()
fresh_norm = (item_last_ts - ts_min) / (ts_max - ts_min + 1e-8)

# Коэффициенты влияния
LAMBDA_POP = 0.05
LAMBDA_FRESH = 0.10

# --------------------------
# 2. Оценка с rerank'ом
# --------------------------
test_df_als = (
    test_df
    .dropna(subset=["uid", "item_id"])
    .astype({"uid": int, "item_id": int})
)

grouped_users = test_df_als.groupby("uid")

overall_recall = []
overall_ndcg = []

for uid, group in tqdm(grouped_users):

    user_true = list(set(group["item_id"]))
    if not user_true:
        continue

    user_items = user_item_matrix[uid]  # train-интеракции юзера

    # Берём большой пул кандидатов из ALS
    rec_items, rec_scores = model.recommend(
        userid=uid,
        user_items=user_items,
        N=CAND_K,
        filter_already_liked_items=True,
        return_scores=True,
    )

    # Добавляем популярность и свежесть
    rerank_scores = (
        rec_scores
        + LAMBDA_POP * pop_norm[rec_items]
        + LAMBDA_FRESH * fresh_norm[rec_items]
    )

    # Сортируем по новому скору
    order = np.argsort(-rerank_scores)
    rec_items_final = rec_items[order][:K]

    # Метрики по item_id
    recall = recall_at_k(rec_items_final, user_true, K)
    ndcg   = ndcg_at_k(rec_items_final, user_true, K)

    overall_recall.append(recall)
    overall_ndcg.append(ndcg)

print("Mean Recall@10:", np.mean(overall_recall))
print("Mean NDCG@10 :", np.mean(overall_ndcg))

# %% [markdown]
# # учет свежести и тд

# %% [markdown]
# ## LightFM (BPR)

# %%
# | 3️⃣ Базовый бейзлайн | Популярные товары, рекомендации по категориям |
# | 4️⃣ Коллаборативная фильтрация | ALS / LightFM модели |
# | 5️⃣ Контентная модель | TF-IDF + косинусное сходство по описаниям |
# | 6️⃣ Гибридная модель | Комбинация скорингов CF и Content-base

# %% [markdown]
# LightFM — это библиотека для построения рекомендательных систем, основанная на факторизации матриц и поддерживающая как коллаборативную фильтрацию, так и контентные признаки пользователей и объектов. Модель объединяет идеи latent factor models и линейных моделей по фичам, что делает её гибридной и подходящей для сценариев cold-start.
#
# В LightFM каждая сущность — пользователь, объект или их признак — представлена эмбеддингом фиксированной размерности. Предсказание предпочтения вычисляется как сумма скалярных произведений эмбеддингов пользователя и объекта, а также их фич. Обучение происходит стохастически (SGD + AdaGrad), с возможностью выбора функции потерь под конкретную задачу:
#
# WARP (Weighted Approximate-Rank Pairwise) — оптимизация ранжирования для implicit feedback, ориентирована на улучшение позиции релевантных объектов в топе.
#
# BPR (Bayesian Personalized Ranking) — парное ранжирование для implicit данных.
#
# Logistic — бинарная классификация для явных оценок.
#
# WARP-kos — ускоренная версия WARP.
#
# Модель эффективно работает с разреженными матрицами, позволяет использовать как только интеракции, так и богатые наборы признаков (категории, теги, демография, TF-IDF и др.), и масштабируется на большие датасеты за счёт многопоточности.

# %%
from lightfm import LightFM
from lightfm.data import Dataset
from scipy.sparse import coo_matrix


model = LightFM(
    loss='bpr',
    no_components=128,
    learning_rate=0.1,
    random_state=42
)

model.fit(
    user_item_matrix,
    epochs=30,
    num_threads=4,
    verbose=True      
)
# Out:
# Epoch:  10%|███████▉                                                                       | 3/30 [03:34<32:12, 71.58s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 13
#       3 from scipy.sparse import coo_matrix
#       6 model = LightFM(
#       7     loss='bpr',
#       8     no_components=128,
#       9     learning_rate=0.1,
#      10     random_state=42
#      11 )
# ---> 13 model.fit(
#      14     user_item_matrix,
#      15     epochs=30,
#      16     num_threads=4,
#      17     verbose=True
#      18 )
#
# File /opt/venv/lib/python3.11/site-packages/lightfm/lightfm.py:550, in LightFM.fit(self, interactions, user_features, item_features, sample_weight, epochs, num_threads, verbose)
#     547 # Discard old results, if any
#     548 self._reset_state()
# --> 550 return self.fit_partial(
#     551     interactions,
#     552     user_features=user_features,
#     553     item_features=item_features,
#     554     sample_weight=sample_weight,
#     555     epochs=epochs,
#     556     num_threads=num_threads,
#     557     verbose=verbose,
#     558 )
#
# File /opt/venv/lib/python3.11/site-packages/lightfm/lightfm.py:655, in LightFM.fit_partial(self, interactions, user_features, item_features, sample_weight, epochs, num_threads, verbose)
#     652     raise ValueError("Number of threads must be 1 or larger.")
#     654 for _ in self._progress(epochs, verbose=verbose):
# --> 655     self._run_epoch(
#     656         item_features,
#     657         user_features,
#     658         interactions,
#     659         sample_weight_data,
#     660         num_threads,
#     661         self.loss,
#     662     )
#     664     self._check_finite()
#     666 return self
#
# File /opt/venv/lib/python3.11/site-packages/lightfm/lightfm.py:713, in LightFM._run_epoch(self, item_features, user_features, interactions, sample_weight, num_threads, loss)
#     696     fit_warp(
#     697         CSRMatrix(item_features),
#     698         CSRMatrix(user_features),
#    (...)    710         self.random_state,
#     711     )
#     712 elif loss == "bpr":
# --> 713     fit_bpr(
#     714         CSRMatrix(item_features),
#     715         CSRMatrix(user_features),
#     716         positives_lookup,
#     717         interactions.row,
#     718         interactions.col,
#     719         interactions.data,
#     720         sample_weight,
#     721         shuffle_indices,
#     722         lightfm_data,
#     723         self.learning_rate,
#     724         self.item_alpha,
#     725         self.user_alpha,
#     726         num_threads,
#     727         self.random_state,
#     728     )
#     729 elif loss == "warp-kos":
#     730     fit_warp_kos(
#     731         CSRMatrix(item_features),
#     732         CSRMatrix(user_features),
#    (...)    743         self.random_state,
#     744     )
#
# KeyboardInterrupt:

# %%
from tqdm import tqdm
import numpy as np

# %%
# Метод ALS может работать только с данными которые он уже видел. 
# оставляет только тех кто был в обучающей выборке


test_df_als = test_df.dropna(subset=["uid", "item_id"]).astype({"uid": int, "item_id": int}) 

grouped_users = test_df_als.groupby("uid")
overall_recall = []
overall_ndcg = []
for uid, group in tqdm(grouped_users):
    # print(list(group["item_id"]))
    user_true = list(set(group["item_id"]))


    user_interactions = user_item_matrix[uid].toarray().ravel()

    items = np.where(user_interactions == 0)[0]  # unseen items

    scores = model.predict(uid, items)

    ranked_idx = np.argsort(-scores)
    ranked_items = items[ranked_idx]

    topk_items = ranked_items[:10]
    
    recall = recall_at_k(topk_items, user_true,  10)
    ndcg = ndcg_at_k(topk_items ,user_true,  10)
    print(ndcg)
    overall_recall.append(recall)
    overall_ndcg.append(ndcg)

print(np.mean(overall_recall))
print(np.mean(overall_ndcg))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 4976/4976 [09:07<00:00,  9.09it/s]
# 0.0032239811509166983
# 0.011410755967998986

# %%
import pandas as  pd
data = pd.read_parquet("album_item_mapping.parquet", engine="fastparquet")
